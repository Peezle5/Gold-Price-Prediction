# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
g_prices=pd.read_csv("gld_price_data.csv")
g_prices
# Out:
#            Date          SPX         GLD        USO      SLV   EUR/USD
# 0      1/2/2008  1447.160034   84.860001  78.470001  15.1800  1.471692
# 1      1/3/2008  1447.160034   85.570000  78.370003  15.2850  1.474491
# 2      1/4/2008  1411.630005   85.129997  77.309998  15.1670  1.475492
# 3      1/7/2008  1416.180054   84.769997  75.500000  15.0530  1.468299
# 4      1/8/2008  1390.189941   86.779999  76.059998  15.5900  1.557099
# ...         ...          ...         ...        ...      ...       ...
# 2285   5/8/2018  2671.919922  124.589996  14.060000  15.5100  1.186789
# 2286   5/9/2018  2697.790039  124.330002  14.370000  15.5300  1.184722
# 2287  5/10/2018  2723.070068  125.180000  14.410000  15.7400  1.191753
# 2288  5/14/2018  2730.129883  124.489998  14.380000  15.5600  1.193118
# 2289  5/16/2018  2725.780029  122.543800  14.405800  15.4542  1.182033
#
# [2290 rows x 6 columns]

# %%
g_prices.head()
# Out:
#        Date          SPX        GLD        USO     SLV   EUR/USD
# 0  1/2/2008  1447.160034  84.860001  78.470001  15.180  1.471692
# 1  1/3/2008  1447.160034  85.570000  78.370003  15.285  1.474491
# 2  1/4/2008  1411.630005  85.129997  77.309998  15.167  1.475492
# 3  1/7/2008  1416.180054  84.769997  75.500000  15.053  1.468299
# 4  1/8/2008  1390.189941  86.779999  76.059998  15.590  1.557099

# %%
g_prices.tail()
# Out:
#            Date          SPX         GLD      USO      SLV   EUR/USD
# 2285   5/8/2018  2671.919922  124.589996  14.0600  15.5100  1.186789
# 2286   5/9/2018  2697.790039  124.330002  14.3700  15.5300  1.184722
# 2287  5/10/2018  2723.070068  125.180000  14.4100  15.7400  1.191753
# 2288  5/14/2018  2730.129883  124.489998  14.3800  15.5600  1.193118
# 2289  5/16/2018  2725.780029  122.543800  14.4058  15.4542  1.182033

# %%
g_prices.dtypes
# Out:
# Date        object
# SPX        float64
# GLD        float64
# USO        float64
# SLV        float64
# EUR/USD    float64
# dtype: object

# %%
#getting information about the data
g_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2290 entries, 0 to 2289
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     2290 non-null   object
#  1   SPX      2290 non-null   float64
#  2   GLD      2290 non-null   float64
#  3   USO      2290 non-null   float64
#  4   SLV      2290 non-null   float64
#  5   EUR/USD  2290 non-null   float64
# dtypes: float64(5), object(1)
# memory usage: 107.5+ KB

# %%
#number of rows and column
g_prices.shape
# Out:
# (2290, 6)

# %%
#checking the number of missing values 
g_prices.isnull().sum()
# Out:
# Date       0
# SPX        0
# GLD        0
# USO        0
# SLV        0
# EUR/USD    0
# dtype: int64

# %% [markdown]
# # Features
# ## . Date
# ## . SPX
# ## . USO
# ## . SLV
# ## . EUR/USD

# %%
#dir(g_prices)

# %%
#getting statistical measures of the data
g_prices.describe()
# Out:
#                SPX          GLD          USO          SLV      EUR/USD
# count  2290.000000  2290.000000  2290.000000  2290.000000  2290.000000
# mean   1654.315776   122.732875    31.842221    20.084997     1.283653
# std     519.111540    23.283346    19.523517     7.092566     0.131547
# min     676.530029    70.000000     7.960000     8.850000     1.039047
# 25%    1239.874969   109.725000    14.380000    15.570000     1.171313
# 50%    1551.434998   120.580002    33.869999    17.268500     1.303296
# 75%    2073.010070   132.840004    37.827501    22.882499     1.369971
# max    2872.870117   184.589996   117.480003    47.259998     1.598798

# %%
correlation=g_prices.corr()
correlation
# Out:
#               SPX       GLD       USO       SLV   EUR/USD
# SPX      1.000000  0.049345 -0.591573 -0.274055 -0.672017
# GLD      0.049345  1.000000 -0.186360  0.866632 -0.024375
# USO     -0.591573 -0.186360  1.000000  0.167547  0.829317
# SLV     -0.274055  0.866632  0.167547  1.000000  0.321631
# EUR/USD -0.672017 -0.024375  0.829317  0.321631  1.000000

# %%
#contructing a heatmap for clearer visualization
plt.figure(figsize=(8,8))
sns.heatmap(correlation, cbar=True, square=True, fmt='.1f', annot=True, cmap='Blues')
#cbar=scalar bar, square=shape, .1f= number of decimal points(1 floating point, annot=name of the columns, cmap=blue(colour of the map)
# Out:
# <AxesSubplot:>

# %%
#checking the distribution of the GLD prices
sns.distplot(g_prices['GLD'], color='purple')
# Out:
# <AxesSubplot:xlabel='GLD', ylabel='Density'>

# %%
sns.displot(g_prices['GLD'], color='blue')
('Skewness: %f', g_prices['GLD'].skew())
('Kurtosis: %f'% g_prices['GLD'].kurt())
# Out:
# 'Kurtosis: -0.275081'

# %%
#plot colums distribution as histogram
g_prices.hist(figsize=(10,8))
# Out:
# array([[<AxesSubplot:title={'center':'SPX'}>,
#         <AxesSubplot:title={'center':'GLD'}>],
#        [<AxesSubplot:title={'center':'USO'}>,
#         <AxesSubplot:title={'center':'SLV'}>],
#        [<AxesSubplot:title={'center':'EUR/USD'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
#change date columns to datetime create year column
g_prices['Date']=pd.to_datetime(g_prices['Date'])
g_prices['Year']=pd.DatetimeIndex(g_prices['Date']).year
g_prices
# Out:
#            Date          SPX         GLD        USO      SLV   EUR/USD  Year
# 0    2008-01-02  1447.160034   84.860001  78.470001  15.1800  1.471692  2008
# 1    2008-01-03  1447.160034   85.570000  78.370003  15.2850  1.474491  2008
# 2    2008-01-04  1411.630005   85.129997  77.309998  15.1670  1.475492  2008
# 3    2008-01-07  1416.180054   84.769997  75.500000  15.0530  1.468299  2008
# 4    2008-01-08  1390.189941   86.779999  76.059998  15.5900  1.557099  2008
# ...         ...          ...         ...        ...      ...       ...   ...
# 2285 2018-05-08  2671.919922  124.589996  14.060000  15.5100  1.186789  2018
# 2286 2018-05-09  2697.790039  124.330002  14.370000  15.5300  1.184722  2018
# 2287 2018-05-10  2723.070068  125.180000  14.410000  15.7400  1.191753  2018
# 2288 2018-05-14  2730.129883  124.489998  14.380000  15.5600  1.193118  2018
# 2289 2018-05-16  2725.780029  122.543800  14.405800  15.4542  1.182033  2018
#
# [2290 rows x 7 columns]

# %%
#plot max vs average yearly Gold prices
g_prices.groupby('Year').max()['GLD'].plot(color='green', label='Max')
g_prices.groupby('Year').mean()['GLD'].plot(color='blue', label='Average')
plt.ylabel('Gold Price')
plt.legend()
plt.title('Max vs Average Yearly Gold Prices')
plt.grid()

# %% [markdown]
# ## According to the graph, gold prices reached its highest point between 2011 and 2013 and from 2015, prices kept increasing gradually

# %%
#from scipy.stats import norm
#plt.hist(g_prices.GLD, bins=20, rwidth=0.8, density=True)
#plt.xlabel('GLD')
#plt.ylabel('Count')

#rng=np.arange(g_prices.GLD.min(), g_prices.GLD.max(), 0.1)
#plt.plot(rng, norm.pdf(rng, g_prices.GLD.mean(), g_prices.GLD.std()))

# %%
#splitting the features and target
X=g_prices.drop(['Date', 'GLD'], axis=1) #features
y=g_prices['GLD'] #target

# %%
X.head()
# Out:
#            SPX        USO     SLV   EUR/USD  Year
# 0  1447.160034  78.470001  15.180  1.471692  2008
# 1  1447.160034  78.370003  15.285  1.474491  2008
# 2  1411.630005  77.309998  15.167  1.475492  2008
# 3  1416.180054  75.500000  15.053  1.468299  2008
# 4  1390.189941  76.059998  15.590  1.557099  2008

# %%
y.head()
# Out:
# 0    84.860001
# 1    85.570000
# 2    85.129997
# 3    84.769997
# 4    86.779999
# Name: GLD, dtype: float64

# %%
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %%
#splitting the data set into training data and test data
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.2, random_state=2)

# %%
#using random forest regression
from sklearn.ensemble import RandomForestRegressor

# %%
model=RandomForestRegressor(n_estimators=100)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_predicted=model.predict(X_test)
y_predicted
# Out:
# array([168.51669968,  81.56980021, 116.34600016, 127.64250055,
#        120.4329014 , 155.01169764, 150.40539805, 126.19090009,
#        117.60939888, 126.00260092, 116.22340147, 171.99400084,
#        141.97209795, 167.89279884, 115.16580064, 117.7620007 ,
#        138.56680252, 170.46920096, 159.68490321, 157.99309942,
#        155.15720008, 122.85160006, 175.57769968, 156.83250353,
#        125.22290051,  93.59069963,  76.70460045, 120.23950029,
#        119.02799941, 167.51819906,  88.03300058, 125.36019987,
#         91.01950066, 117.71100035, 121.00739911, 135.86240045,
#        115.42930103, 114.61960085, 145.99399965, 107.48930118,
#        105.67360251,  87.07379754, 126.41550072, 117.68170048,
#        155.49039873, 120.05509959, 108.43300001, 108.02549847,
#         93.20760065, 127.11559787,  74.92270024, 113.58019986,
#        120.52359971, 111.28169929, 118.96879881, 120.34269954,
#        159.57440027, 167.87110123, 147.01229703,  86.03029892,
# ...

# %%
#X_test

# %%
len(X_test)
# Out:
# 458

# %%
#X_train

# %%
len(X_train)
# Out:
# 1832

# %%
y_test
# Out:
# [168.020004,
#  81.230003,
#  112.32,
#  127.589996,
#  119.620003,
#  154.21000700000002,
#  148.91000400000001,
#  126.190002,
#  117.470001,
#  125.739998,
#  115.379997,
#  167.119995,
#  141.630005,
#  169.559998,
#  115.599998,
#  119.66999799999999,
#  132.949997,
#  170.399994,
#  159.369995,
#  173.529999,
#  154.720001,
#  128.119995,
#  177.720001,
#  157.190002,
#  125.309998,
#  93.400002,
#  76.790001,
#  119.690002,
#  118.989998,
#  167.389999,
#  87.5,
#  124.980003,
#  91.230003,
#  115.489998,
#  120.949997,
#  133.809998,
#  116.690002,
#  113.809998,
#  133.580002,
#  105.970001,
#  105.120003,
#  87.959999,
#  126.82,
#  116.860001,
#  159.259995,
#  119.459999,
#  109.160004,
#  108.620003,
#  93.269997,
#  127.160004,
#  72.260002,
#  113.470001,
#  119.68,
#  109.139999,
#  119.309998,
#  120.050003,
#  159.889999,
#  161.490005,
#  146.740005,
#  85.809998,
#  93.709999,
#  85.550003,
#  91.029999,
#  118.489998,
#  126.449997,
#  126.980003,
#  171.699997,
# ...

# %%
#converting the values of y_test into a list
y_test=list(y_test)
y_test
# Out:
# [168.020004,
#  81.230003,
#  112.32,
#  127.589996,
#  119.620003,
#  154.21000700000002,
#  148.91000400000001,
#  126.190002,
#  117.470001,
#  125.739998,
#  115.379997,
#  167.119995,
#  141.630005,
#  169.559998,
#  115.599998,
#  119.66999799999999,
#  132.949997,
#  170.399994,
#  159.369995,
#  173.529999,
#  154.720001,
#  128.119995,
#  177.720001,
#  157.190002,
#  125.309998,
#  93.400002,
#  76.790001,
#  119.690002,
#  118.989998,
#  167.389999,
#  87.5,
#  124.980003,
#  91.230003,
#  115.489998,
#  120.949997,
#  133.809998,
#  116.690002,
#  113.809998,
#  133.580002,
#  105.970001,
#  105.120003,
#  87.959999,
#  126.82,
#  116.860001,
#  159.259995,
#  119.459999,
#  109.160004,
#  108.620003,
#  93.269997,
#  127.160004,
#  72.260002,
#  113.470001,
#  119.68,
#  109.139999,
#  119.309998,
#  120.050003,
#  159.889999,
#  161.490005,
#  146.740005,
#  85.809998,
#  93.709999,
#  85.550003,
#  91.029999,
#  118.489998,
#  126.449997,
#  126.980003,
#  171.699997,
# ...

# %%
#plotting the values of actual prices against the predicted prices to know how close the predictions are to the actual prices.
plt.plot(y_test, color='red', label='Actual Value')
plt.plot(y_predicted, color='blue', label='Predicted Value')
plt.title('Actual Price' and 'Predicted Price')
plt.xlabel('Number of values')
plt.ylabel('GLD Price')
plt.legend()

# %%
#evaluate model
MSE= metrics.mean_squared_error(y_test, y_predicted)
MSE
# Out:
# 4.8958172608507535

# %%
#R squared error(coefficient of determination instead of accuracy score)
r_2=metrics.r2_score(y_test, y_predicted) 
r_2
# Out:
# 0.990717835645365
